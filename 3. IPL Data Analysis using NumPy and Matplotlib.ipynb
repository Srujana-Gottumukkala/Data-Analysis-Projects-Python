# %%
import warnings
warnings.filterwarnings('ignore')

# To ignore the error message

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
Salary
# Out:
# array([[15946875, 17718750, 19490625, 21262500, 23034375, 24806250,
#         25244493, 27849149, 30453805, 23500000],
#        [12000000, 12744189, 13488377, 14232567, 14976754, 16324500,
#         18038573, 19752645, 21466718, 23180790],
#        [ 4621800,  5828090, 13041250, 14410581, 15779912, 14500000,
#         16022500, 17545000, 19067500, 20644400],
#        [ 3713640,  4694041, 13041250, 14410581, 15779912, 17149243,
#         18518574, 19450000, 22407474, 22458000],
#        [ 4493160,  4806720,  6061274, 13758000, 15202590, 16647180,
#         18091770, 19536360, 20513178, 21436271],
#        [ 3348000,  4235220, 12455000, 14410581, 15779912, 14500000,
#         16022500, 17545000, 19067500, 20644400],
#        [ 3144240,  3380160,  3615960,  4574189, 13520500, 14940153,
#         16359805, 17779458, 18668431, 20068563],
#        [       0,        0,  4171200,  4484040,  4796880,  6053663,
#         15506632, 16669630, 17832627, 18995624],
# ...

# %%
Salary[0]
# Out:
# array([15946875, 17718750, 19490625, 21262500, 23034375, 24806250,
#        25244493, 27849149, 30453805, 23500000])

# %%
min(Salary[0])
# Out:
# 15946875

# %%
max(Salary[0])
# Out:
# 30453805

# %%
plt.plot(Salary[0])

# %%
# Explanation - Salary has increased till 2023 and then it has decreased

# %%
plt.plot(Salary[1], ls = '--')
plt.plot(Salary[2], ls = ':')
plt.plot(Salary[3],ls = '--', c = 'k', marker='1', markersize = 10)
plt.plot(Salary[4], c = 'Blue', ls = '-', marker = 's', ms = 5)
plt.plot(Salary[5], c = 'Blue', ls = '-', marker = 's', ms = 5)
# Introducing different line styles

# %%
# Using system parameters- Parameter tuning

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = 7,3

# %%
Sdict
# Out:
# {'2015': 0,
#  '2016': 1,
#  '2017': 2,
#  '2018': 3,
#  '2019': 4,
#  '2020': 5,
#  '2021': 6,
#  '2022': 7,
#  '2023': 8,
#  '2024': 9}

# %%
Pdict
# Out:
# {'Sachin': 0,
#  'Rahul': 1,
#  'Smith': 2,
#  'Sami': 3,
#  'Pollard': 4,
#  'Morris': 5,
#  'Samson': 6,
#  'Dhoni': 7,
#  'Kohli': 8,
#  'Sky': 9}

# %%
Games
# Out:
# array([[80, 77, 82, 82, 73, 82, 58, 78,  6, 35],
#        [82, 57, 82, 79, 76, 72, 60, 72, 79, 80],
#        [79, 78, 75, 81, 76, 79, 62, 76, 77, 69],
#        [80, 65, 77, 66, 69, 77, 55, 67, 77, 40],
#        [82, 82, 82, 79, 82, 78, 54, 76, 71, 41],
#        [70, 69, 67, 77, 70, 77, 57, 74, 79, 44],
#        [78, 64, 80, 78, 45, 80, 60, 70, 62, 82],
#        [35, 35, 80, 74, 82, 78, 66, 81, 81, 27],
#        [40, 40, 40, 81, 78, 81, 39,  0, 10, 51],
#        [75, 51, 51, 79, 77, 76, 49, 69, 54, 62]])

# %%
# Adding a legend
plt.rcParams['figure.figsize'] = 20,12
plt.plot(Salary[0], c='blue', marker='o', label = Players[0])
plt.plot(Salary[1], c='green', marker='o', label = Players[1])
plt.plot(Salary[2], c='red', marker='o', label = Players[2])
plt.plot(Salary[3], c='cyan', marker='o', label = Players[3])
plt.plot(Salary[4], c='magenta', marker='o',label = Players[4])
plt.plot(Salary[5], c='yellow', marker='o', label = Players[5])
plt.plot(Salary[6], c='black', marker='o', label = Players[6])
plt.plot(Salary[7], c='blue', marker='*', label = Players[7])
plt.plot(Salary[8], c='green', marker='*', label = Players[8])
plt.plot(Salary[9], c='yellow', marker='*', label = Players[9])
plt.legend(prop={'size':14})
plt.xticks(list(range(0,10)), Seasons)    # Rotation of the x-axis markers

plt.show()

# %% [markdown]
# #### Summary
#     import numpy as np
#     import warnings
#     warnings.filterwarnings('ignore')
#     import matplotlib.pyplot as plt
#     %matplotlib inline
#     min(1D array)
#     max()
#     plt.plot()
#     plt.xticks() - xaxis
#     plt.yticks() - yticks
#     plt.rcParams[] = x,y
#     plt.show()
#     plt.legend()
#     More lines make the graph look messy using Python, one needs to migrate to BI tools
